# %% [markdown]
# bubble sort

# %%
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter
from IPython.display import display

# Nama file dataset
file_path = "osn.csv"

# Load dataset
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "anakpindahan/indonesia-national-science-olympiad-osn/versions/10",
    file_path,
)

# Mengambil kolom
df = df[["Medali", "Nama Peserta", "Bidang", "Provinsi"]]

# Mengisi data kosong
df["Medali"] = df["Medali"].fillna("Partisipan")

# =========================
# PRIORITAS MEDALI
# =========================
prioritas_medali = {
    "Emas": 1,
    "Perak": 2,
    "Perunggu": 3,
    "Harapan": 4,
    "Partisipan": 5
}

# Menambahkan kolom prioritas
df["Prioritas"] = df["Medali"].map(prioritas_medali)

# Jika ada medali lain yang tidak dikenal
df["Prioritas"] = df["Prioritas"].fillna(99)

# Mengubah dataframe menjadi list
data = df.values.tolist()

# =========================
# BUBBLE SORT BERDASARKAN MEDALI
# =========================
n = len(data)

for i in range(n):
    for j in range(0, n - i - 1):

        # Index 4 = Prioritas
        if data[j][4] > data[j + 1][4]:

            # Tukar posisi
            data[j], data[j + 1] = data[j + 1], data[j]

# Mengembalikan ke DataFrame
df_sorted = pd.DataFrame(
    data,
    columns=[
        "Medali",
        "Nama Peserta",
        "Bidang",
        "Provinsi",
        "Prioritas"
    ]
)

# Menghapus kolom prioritas
df_sorted = df_sorted.drop(columns=["Prioritas"])

# Index mulai dari 1
df_sorted.index = range(1, len(df_sorted) + 1)

# Pengaturan tampilan
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Menampilkan hasil
display(df_sorted)

# %% [markdown]
# merge sort

# %%
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter
from IPython.display import display

# Nama file dataset
file_path = "osn.csv"

# Load dataset
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "anakpindahan/indonesia-national-science-olympiad-osn/versions/10",
    file_path,
)

# Mengambil kolom yang ingin ditampilkan
df = df[["Medali", "Nama Peserta", "Bidang", "Provinsi"]]

# Mengisi data kosong
df["Medali"] = df["Medali"].fillna("Partisipan")

# =========================
# PRIORITAS MEDALI
# =========================
prioritas_medali = {
    "Emas": 1,
    "Perak": 2,
    "Perunggu": 3,
    "Harapan": 4,
    "Partisipan": 5
}

# Menambahkan kolom prioritas
df["Prioritas"] = df["Medali"].map(prioritas_medali)

# Jika ada medali lain
df["Prioritas"] = df["Prioritas"].fillna(99)

# Mengubah dataframe menjadi list
data = df.values.tolist()

# =========================
# MERGE SORT
# =========================
def merge_sort(arr):

    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2

    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

# =========================
# MERGE FUNCTION
# =========================
def merge(left, right):

    hasil = []

    while len(left) > 0 and len(right) > 0:

        # Index 4 = Prioritas Medali
        if left[0][4] < right[0][4]:

            hasil.append(left.pop(0))

        else:

            hasil.append(right.pop(0))

    # Sisa data
    hasil.extend(left)
    hasil.extend(right)

    return hasil

# Menjalankan Merge Sort
sorted_data = merge_sort(data)

# Mengembalikan ke DataFrame
df_sorted = pd.DataFrame(
    sorted_data,
    columns=[
        "Medali",
        "Nama Peserta",
        "Bidang",
        "Provinsi",
        "Prioritas"
    ]
)

# Menghapus kolom prioritas
df_sorted = df_sorted.drop(columns=["Prioritas"])

# Index mulai dari 1
df_sorted.index = range(1, len(df_sorted) + 1)

# Pengaturan tampilan
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Menampilkan hasil
display(df_sorted)

# %% [markdown]
# shell sort

# %%
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter
from IPython.display import display

# Nama file dataset
file_path = "osn.csv"

# Load dataset
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "anakpindahan/indonesia-national-science-olympiad-osn/versions/10",
    file_path,
)

# Mengambil kolom yang ingin ditampilkan
df = df[["Medali", "Nama Peserta", "Bidang", "Provinsi"]]

# Mengisi data kosong
df["Medali"] = df["Medali"].fillna("Partisipan")

# =========================
# PRIORITAS MEDALI
# =========================
prioritas_medali = {
    "Emas": 1,
    "Perak": 2,
    "Perunggu": 3,
    "Harapan": 4,
    "Partisipan": 5
}

# Menambahkan kolom prioritas
df["Prioritas"] = df["Medali"].map(prioritas_medali)

# Jika ada medali lain
df["Prioritas"] = df["Prioritas"].fillna(99)

# Mengubah dataframe menjadi list
data = df.values.tolist()

# =========================
# SHELL SORT
# =========================
n = len(data)

# Menentukan gap awal
gap = n // 2

while gap > 0:

    for i in range(gap, n):

        temp = data[i]
        j = i

        # Index 4 = Prioritas Medali
        while j >= gap and data[j - gap][4] > temp[4]:

            data[j] = data[j - gap]
            j -= gap

        data[j] = temp

    # Mengurangi gap
    gap //= 2

# Mengembalikan ke DataFrame
df_sorted = pd.DataFrame(
    data,
    columns=[
        "Medali",
        "Nama Peserta",
        "Bidang",
        "Provinsi",
        "Prioritas"
    ]
)

# Menghapus kolom prioritas
df_sorted = df_sorted.drop(columns=["Prioritas"])

# Index mulai dari 1
df_sorted.index = range(1, len(df_sorted) + 1)

# Pengaturan tampilan
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Menampilkan hasil
display(df_sorted)

# %% [markdown]
# mencari, mengurutkan dan menampilkan waktu eksekusi

# %%
# =========================================================
# MENAMPILKAN SELURUH DATA TANPA TERPOTONG
# SEARCHING DATA BESAR OSN
# SEARCH NAMA PESERTA DAN BIDANG
# WAKTU EKSEKUSI
# =========================================================

import pandas as pd
import time 

# =========================================================
# LOAD CSV LOKAL
# =========================================================

df = pd.read_csv("osn.csv")

# ==========================================
# def waktu eksekusi
# ==========================================

start = time.time()

# proses searching

end = time.time()

print("Waktu Eksekusi :", end - start, "detik")

# =========================================================
# AGAR OUTPUT TIDAK TERPOTONG
# =========================================================
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 2000)
pd.set_option('display.max_colwidth', None)

# =========================================================
# DEFINISI BARU:
# MENAMPILKAN SELURUH TEKS BIDANG TANPA TERPOTONG
# =========================================================

def tampilkan_hasil(dataframe):

    if len(dataframe) > 0:

        print("\nDATA DITEMUKAN")
        print("=" * 150)

        # to_string agar output full
        print(dataframe.to_string(index=False))

        print("=" * 150)
        print("Jumlah Data Ditemukan :", len(dataframe))

    else:
        print("Data tidak ditemukan.")

# =========================================================
# MENAMPILKAN JUMLAH DATA
# =========================================================

print("=" * 100)
print("PROGRAM SEARCHING DATA OSN")
print("=" * 100)

print("Jumlah Data :", len(df))

# =========================================================
# MENU SEARCH
# =========================================================

print("\nPILIH JENIS PENCARIAN")
print("1. Cari Nama Peserta")
print("2. Cari Bidang")

pilihan = input("Masukkan pilihan (1/2): ")

# =========================================================
# SEARCH NAMA PESERTA
# =========================================================

if pilihan == "1":

    keyword = input("\nMasukkan nama peserta: ")

    hasil_nama = df[
        df["Nama Peserta"]
        .astype(str)
        .str.contains(keyword, case=False, na=False)
    ]

    tampilkan_hasil(hasil_nama)

# =========================================================
# SEARCH BIDANG
# =========================================================

elif pilihan == "2":

    bidang = input("\nMasukkan bidang: ")

    hasil_bidang = df[
        df["Bidang"]
        .astype(str)
        .str.contains(bidang, case=False, na=False)
    ]

    tampilkan_hasil(hasil_bidang)

# =========================================================
# INPUT SALAH
# =========================================================

else:
    print("Pilihan tidak valid.")
